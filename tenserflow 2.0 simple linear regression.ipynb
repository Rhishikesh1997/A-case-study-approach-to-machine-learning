# %% [markdown]
# ## Simple linear regression  using tenserflow 2.0

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv(r"G:\Rhishi\linear.csv")
data.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
x=data['x']
y=data['y']
x=np.array(x)
x=x.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)


sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from tensorflow.keras.layers import Input, Dense, Activation,Dropout
from tensorflow.keras.models import Model

# %%
input_layer = Input(shape=(x.shape[1],))
dense_layer1 = Dense(100, activation='relu')(input_layer)
dense_layer2 = Dense(50, activation='relu')(dense_layer1)
dense_layer3 = Dense(25, activation='relu')(dense_layer2)
output_layer = Dense(1)(dense_layer3)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(loss="mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])

# %%
model_train = model.fit(X_train, y_train, batch_size=2, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Train on 192 samples, validate on 48 samples
# Epoch 1/100
# 192/192 [==============================] - 2s 8ms/sample - loss: 3150.7609 - mean_squared_error: 3150.7605 - val_loss: 2269.2012 - val_mean_squared_error: 2269.2014
# Epoch 2/100
# 192/192 [==============================] - 0s 3ms/sample - loss: 618.9852 - mean_squared_error: 618.9852 - val_loss: 70.3822 - val_mean_squared_error: 70.3822
# Epoch 3/100
# 192/192 [==============================] - 1s 4ms/sample - loss: 52.6197 - mean_squared_error: 52.6197 - val_loss: 43.3417 - val_mean_squared_error: 43.3417
# Epoch 4/100
# 192/192 [==============================] - 1s 3ms/sample - loss: 31.4037 - mean_squared_error: 31.4037 - val_loss: 23.7571 - val_mean_squared_error: 23.7571
# Epoch 5/100
# 192/192 [==============================] - 1s 3ms/sample - loss: 19.8627 - mean_squared_error: 19.8627 - val_loss: 19.2312 - val_mean_squared_error: 19.2312
# Epoch 6/100
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

pred_train = model.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train)))

pred = model.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 3.0882996344500384
# 2.910619003097644
